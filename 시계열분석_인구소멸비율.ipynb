# %%
library('readxl')
install.packages('anytime')
library(anytime)

top <- read_excel('C:/Users/DJA/Desktop/DataScience/Best10.xlsx')
# Out:
# also installing the dependency 'RApiDatetime'
# package 'RApiDatetime' successfully unpacked and MD5 sums checked
# package 'anytime' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\DJA\AppData\Local\Temp\Rtmp6lX2lU\downloaded_packages
# Warning message in read_fun(path = path, sheet = sheet, limits = limits, shim = shim, :
# "Expecting numeric in A3 / R3C1: got a date"Warning message in read_fun(path = path, sheet = sheet, limits = limits, shim = shim, :
# "Expecting numeric in A5 / R5C1: got a date"Warning message in read_fun(path = path, sheet = sheet, limits = limits, shim = shim, :
# "Expecting numeric in A7 / R7C1: got a date"Warning message in read_fun(path = path, sheet = sheet, limits = limits, shim = shim, :
# "Expecting numeric in A9 / R9C1: got a date"Warning message in read_fun(path = path, sheet = sheet, limits = limits, shim = shim, :
# "Expecting numeric in A11 / R11C1: got a date"Warning message in read_fun(path = path, sheet = sheet, limits = limits, shim = shim, :
# "Expecting numeric in A13 / R13C1: got a date"

# %%
plot(top)
plot(top$년월, top$`경상북도 의성군 춘산면`, type='l')
par(new=T)
plot(top$년월, top$`경상남도 합천군 봉산면`, type='l', col='red')
par(new=T)
plot(top$년월, top$`경상남도 거창군 가조면`, type='l', col='blue')
par(new=T)
plot(top$년월, top$`인천광역시 서구 신현원창동`, type='l', col='orange')
par(new=T)
plot(top$년월, top$`경상북도 청송군 안덕면`, type='l', col='tomato1')
par(new=T)
plot(top$년월, top$`인천광역시 서구 가좌2동`, type='l', col='violetred1')
par(new=T)

str(top)
# Out:
# plot without title
# Classes 'tbl_df', 'tbl' and 'data.frame':	120 obs. of  11 variables:
#  $ 년월                      : num  200801 200802 200803 200804 200805 ...
#  $ 경상북도 의성군 춘산면    : num  0.488 0.485 0.484 0.477 0.479 ...
#  $ 경상남도 합천군 봉산면    : num  0.399 0.407 0.393 0.371 0.368 ...
#  $ 경상남도 거창군 가조면    : num  0.448 0.437 0.425 0.42 0.419 ...
#  $ 인천광역시 서구 신현원창동: num  5.42 5.38 5.3 5.32 5.25 ...
#  $ 경상북도 청송군 안덕면    : num  0.46 0.461 0.452 0.446 0.441 ...
#  $ 경상북도 군위군 우보면    : num  0.296 0.294 0.281 0.279 0.279 ...
#  $ 경상남도 거창군 거창읍    : num  2.28 2.28 2.26 2.24 2.24 ...
#  $ 경상북도 의성군 비안면    : num  0.375 0.366 0.361 0.353 0.358 ...
#  $ 인천광역시 서구 가좌2동   : num  5.07 5.11 5.16 5.17 5.19 ...
#  $ 전라남도 고흥군 두원면    : num  0.279 0.276 0.275 0.275 0.272 ...
# plot without title

# %%
Date <- anydate(top$년월)
str(top)
# Out:
# Classes 'tbl_df', 'tbl' and 'data.frame':	120 obs. of  11 variables:
#  $ 년월                      : num  200801 200802 200803 200804 200805 ...
#  $ 경상북도 의성군 춘산면    : num  0.488 0.485 0.484 0.477 0.479 ...
#  $ 경상남도 합천군 봉산면    : num  0.399 0.407 0.393 0.371 0.368 ...
#  $ 경상남도 거창군 가조면    : num  0.448 0.437 0.425 0.42 0.419 ...
#  $ 인천광역시 서구 신현원창동: num  5.42 5.38 5.3 5.32 5.25 ...
#  $ 경상북도 청송군 안덕면    : num  0.46 0.461 0.452 0.446 0.441 ...
#  $ 경상북도 군위군 우보면    : num  0.296 0.294 0.281 0.279 0.279 ...
#  $ 경상남도 거창군 거창읍    : num  2.28 2.28 2.26 2.24 2.24 ...
#  $ 경상북도 의성군 비안면    : num  0.375 0.366 0.361 0.353 0.358 ...
#  $ 인천광역시 서구 가좌2동   : num  5.07 5.11 5.16 5.17 5.19 ...
#  $ 전라남도 고흥군 두원면    : num  0.279 0.276 0.275 0.275 0.272 ...

# %%
library(zoo)

dates <- as.yearmon(2008 + seq(0,119)/12)
dates
# Out:
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#   [1] "1 2008"  "2 2008"  "3 2008"  "4 2008"  "5 2008"  "6 2008"  "7 2008"
#   [8] "8 2008"  "9 2008"  "10 2008" "11 2008" "12 2008" "1 2009"  "2 2009"
#  [15] "3 2009"  "4 2009"  "5 2009"  "6 2009"  "7 2009"  "8 2009"  "9 2009"
#  [22] "10 2009" "11 2009" "12 2009" "1 2010"  "2 2010"  "3 2010"  "4 2010"
#  [29] "5 2010"  "6 2010"  "7 2010"  "8 2010"  "9 2010"  "10 2010" "11 2010"
#  [36] "12 2010" "1 2011"  "2 2011"  "3 2011"  "4 2011"  "5 2011"  "6 2011"
#  [43] "7 2011"  "8 2011"  "9 2011"  "10 2011" "11 2011" "12 2011" "1 2012"
#  [50] "2 2012"  "3 2012"  "4 2012"  "5 2012"  "6 2012"  "7 2012"  "8 2012"
#  [57] "9 2012"  "10 2012" "11 2012" "12 2012" "1 2013"  "2 2013"  "3 2013"
#  [64] "4 2013"  "5 2013"  "6 2013"  "7 2013"  "8 2013"  "9 2013"  "10 2013"
#  [71] "11 2013" "12 2013" "1 2014"  "2 2014"  "3 2014"  "4 2014"  "5 2014"
#  [78] "6 2014"  "7 2014"  "8 2014"  "9 2014"  "10 2014" "11 2014" "12 2014"
#  [85] "1 2015"  "2 2015"  "3 2015"  "4 2015"  "5 2015"  "6 2015"  "7 2015"
#  [92] "8 2015"  "9 2015"  "10 2015" "11 2015" "12 2015" "1 2016"  "2 2016"
#  [99] "3 2016"  "4 2016"  "5 2016"  "6 2016"  "7 2016"  "8 2016"  "9 2016"
# [106] "10 2016" "11 2016" "12 2016" "1 2017"  "2 2017"  "3 2017"  "4 2017"
# [113] "5 2017"  "6 2017"  "7 2017"  "8 2017"  "9 2017"  "10 2017" "11 2017"
# [120] "12 2017"

# %%
a <- zoo(top$`경상북도 의성군 춘산면`, dates)
str(a)
b <- as.matrix(a)
c<- as.vector(b)
d <- ts(log(c), frequency = 8) # ts = 역행렬로 바꿔야함
# Out:
# 'zoo' series from 1 2008 to 12 2017
#   Data: num [1:120] 0.488 0.485 0.484 0.477 0.479 ...
#   Index: Class 'yearmon'  num [1:120] 2008 2008 2008 2008 2008 ...

# %%
plot(a)
plot(d,xlab = '월', ylab= '소멸비율')
# Out:
# Plot with title ""
# plot without title

# %%
#전체를 기준으로 잘라서 추세를 그래프로 확인
best1 <- zoo(top$`인천광역시 서구 신현원창동`, top$년월)
plot(best1)
str(best1)
best1
# Out:
# 'zoo' series from 200801 to 201712
#   Data: num [1:120] 5.42 5.38 5.3 5.32 5.25 ...
#   Index:  num [1:120] 200801 200802 200803 200804 200805 ...
#     200801     200802     200803     200804     200805     200806     200807
# 5.41988950 5.38489871 5.30100640 5.32225300 5.24885216 5.21139706 5.13840513
#     200808     200809     200810     200811     200812     200901     200902
# 5.06934307 4.99102334 4.94894366 4.90671317 4.86185925 0.21839080 0.22222222
#     200903     200904     200905     200906     200907     200908     200909
# 0.23255814 0.21301775 0.21428571 0.21686747 0.21686747 0.20359281 0.21556886
#     200910     200911     200912     201001     201002     201003     201004
# 0.24489796 0.24489796 0.24657534 0.38772664 0.39106145 0.38997214 0.37377964
#     201005     201006     201007     201008     201009     201010     201011
# 0.37273992 0.37830320 0.38557559 0.38227147 0.37517241 0.38159675 0.37837838
#     201012     201101     201102     201103     201104     201105     201106
# 0.37720488 1.22007722 1.27906977 1.28627451 1.30158730 1.29921260 1.30980392
#     201107     201108     201109     201110     201111     201112     201201
# 1.29411765 1.27559055 1.25096525 1.21839081 1.20152091 1.22605364 0.94819466
#     201202     201203     201204     201205     201206     201207     201208
# 0.92555960 0.90701891 0.90079876 0.89491179 0.88792664 0.89068826 0.87927565
#     201209     201210     201211     201212     201301     201302     201303
# 0.87716654 0.86716792 0.85821455 0.85935548 1.21205357 1.18477044 1.18171683
#     201304     201305     201306     201307     201308     201309     201310
# 1.19776536 1.20538721 1.22522522 1.27721661 1.28603604 1.27721661 1.29729730
#     201311     201312     201401     201402     201403     201404     201405
# 1.29875987 1.28555431 0.54666667 0.51973684 0.47524753 0.48344371 0.49342105
#     201406     201407     201408     201409     201410     201411     201412
# 0.52666667 0.53156146 0.53156146 0.54304636 0.53420195 0.54071661 0.55194805
#     201501     201502     201503     201504     201505     201506     201507
# 1.22030238 1.21114684 1.17344754 1.16433942 1.14898178 1.15969989 1.15268817
#     201508     201509     201510     201511     201512     201601     201602
# 1.15334773 1.15517241 1.15053763 1.15053763 1.12931034 0.16279070 0.14117647
#     201603     201604     201605     201606     201607     201608     201609
# 0.12048193 0.14457831 0.17073171 0.17073171 0.17283951 0.17073171 0.16279070
#     201610     201611     201612     201701     201702     201703     201704
# 0.16470588 0.16470588 0.13953488 0.13953488 0.13953488 0.11627907 0.09302326
#     201705     201706     201707     201708     201709     201710     201711
# 0.11764706 0.11627907 0.11494253 0.11363636 0.11235955 0.11235955 0.11235955
#     201712
# 0.08988764
# Plot with title ""

# %%
#시간에 따른 변화량 확인 - 차분(현재값-이전값)
plot(diff(d))
acf(d)
head(d)
# Out:
# plot without title
# [1] -0.7181932 -0.7236976 -0.7254660 -0.7401721 -0.7366323 -0.7476071
# Plot with title "Series  d"

# %%
Box.test(d, type='Ljung-Box') #box-pierce검증
Box.test
# Out:
# 	Box-Ljung test
#
# data:  d
# X-squared = 101.18, df = 1, p-value < 2.2e-16
# function (x, lag = 1, type = c("Box-Pierce", "Ljung-Box"), fitdf = 0)
# {
#     if (NCOL(x) > 1)
#         stop("x is not a vector or univariate time series")
#     DNAME <- deparse(substitute(x))
#     type <- match.arg(type)
#     cor <- acf(x, lag.max = lag, plot = FALSE, na.action = na.pass)
#     n <- sum(!is.na(x))
#     PARAMETER <- c(df = lag - fitdf)
#     obs <- cor$acf[2:(lag + 1)]
#     if (type == "Box-Pierce") {
#         METHOD <- "Box-Pierce test"
#         STATISTIC <- n * sum(obs^2)
#         PVAL <- 1 - pchisq(STATISTIC, lag - fitdf)
#     }
#     else {
#         METHOD <- "Box-Ljung test"
#         STATISTIC <- n * (n + 2) * sum(1/seq.int(n - 1, n - lag) *
#             obs^2)
#         PVAL <- 1 - pchisq(STATISTIC, lag - fitdf)
#     }
#     names(STATISTIC) <- "X-squared"
#     structure(list(statistic = STATISTIC, parameter = PARAMETER,
#         p.value = PVAL, method = METHOD, data.name = DNAME),
#         class = "htest")
# }
# <bytecode: 0x0000000040424e80>
# <environment: namespace:stats>

# %%
#이동평균법으로 시계열 그래프를 좀 더 부드럽게 표시
#데이터들을 몇개씩 묶어서 평균을 내어 새로운 값 구함.
#이동평균으로 새로운 값을 구하면 복잡한 선들이 좀더 부드럽게 표시 - 재략적인 패턴 파악 쉽다.
plot(a)
par(mfrow=c(2,2))
roll2 <- rollapply(a, 2, mean) #숫자는 몇개씩 묶어서 평균을 낼 것이다.
roll4 <- rollapply(a, 4, mean)
roll6 <- rollapply(a, 6, mean)
roll8 <- rollapply(a, 8, mean)
plot(roll2); plot(roll4); 
plot(roll6); plot(roll8);
# Out:
# Plot with title ""
# Plot with title ""

# %%
#이동평균의 묶음 width수는 얼마나 좋을까?
#adf를 통해 구한 자기상관수를 사용하자.
par(mfrow=c(1,1))
roll11 <- rollapply(a, 11, mean)
plot(roll11)
# Out:
# Plot with title ""

# %%
#예측값 계산. - 시계열 모형 생성 : ARIMA모델
#R에서는 auto.arima 만능함수를 사용.
install.packages("forecast")
library(forecast)
library(TTR)
fit1 <- auto.arima(ts(log(c), frequency = 12))
plot(forecast(fit1))
fit1 <- auto.arima(ts(log(c), frequency=12))
fit2 <- auto.arima(ts(log(c), frequency=12))
# Out:
# also installing the dependencies 'quadprog', 'tseries', 'fracdiff', 'lmtest', 'RcppArmadillo'
# package 'quadprog' successfully unpacked and MD5 sums checked
# package 'tseries' successfully unpacked and MD5 sums checked
# package 'fracdiff' successfully unpacked and MD5 sums checked
# package 'lmtest' successfully unpacked and MD5 sums checked
# package 'RcppArmadillo' successfully unpacked and MD5 sums checked
# package 'forecast' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\DJA\AppData\Local\Temp\Rtmp6lX2lU\downloaded_packages
# Plot with title "Forecasts from ARIMA(1,0,0)(2,0,0)[12] with non-zero mean"

# %%
#생선된 모형으로 값 예측
v <- predict(fit2, n.ahead=12) #향후 12달예측.
v

plot(a)
# Out:
# $pred
#          Jan       Feb       Mar       Apr       May       Jun       Jul
# 11 -1.563443 -1.572013 -1.569241 -1.568981 -1.566554 -1.574400 -1.579049
#          Aug       Sep       Oct       Nov       Dec
# 11 -1.583542 -1.580350 -1.590660 -1.584879 -1.578857
#
# $se
#          Jan       Feb       Mar       Apr       May       Jun       Jul
# 11 0.1872082 0.2597900 0.3122901 0.3540179 0.3886737 0.4182035 0.4437920
#          Aug       Sep       Oct       Nov       Dec
# 11 0.4662300 0.4860790 0.5037572 0.5195866 0.5338221
# Plot with title ""
